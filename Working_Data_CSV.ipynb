# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings

# %%
CDCData = pd.read_csv('static/data/fl_clean_data.csv')

CDCData
# Out:
#     StateAbbr StateDesc          PlaceName  PlaceFIPS  TotalPopulation  \
# 0          FL   Florida    Fort Lauderdale    1224000           165528
# 1          FL   Florida         Fort White    1224500              568
# 2          FL   Florida            Memphis    1244175             8257
# 3          FL   Florida      Miami Gardens    1245060           107042
# 4          FL   Florida  North Miami Beach    1249475            42521
# ..        ...       ...                ...        ...              ...
# 895        FL   Florida      Fisher Island    1222375              126
# 896        FL   Florida         Palm Coast    1254200            75196
# 897        FL   Florida        Indialantic    1233375             2739
# 898        FL   Florida         Belle Isle    1205300             6268
# 899        FL   Florida              Tampa    1271000           335761
#
#      ACCESS2_CrudePrev ACCESS2_Crude95CI  ACCESS2_AdjPrev ACCESS2_Adj95CI  \
# ...
